# %%
import threading

# Helper thread to avoid the Spark StreamingContext from blocking Jupyter
        
class StreamingThread(threading.Thread):
    def __init__(self, ssc):
        super().__init__()
        self.ssc = ssc
    def run(self):
        self.ssc.start()
        self.ssc.awaitTermination()
    def stop(self):
        print('----- Stopping... this may take a few seconds -----')
        self.ssc.stop(stopSparkContext=False, stopGraceFully=True)

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Romain-Laptop.lan:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import random
from pyspark.streaming import StreamingContext
from pyspark.sql import Row
from pyspark.sql.functions import udf, struct, array, col, lit
from pyspark.sql.types import StringType

# %%
from pyspark.ml.pipeline import PipelineModel
from pyspark.sql.types import IntegerType

pipeline_model = PipelineModel.load(r"C:\Users\Romain\databricks\gbt_modelw2v")

def process(time, rdd):
    if rdd.isEmpty():
        return

    df = spark.read.json(rdd)
    print("========= %s =========" % str(time))    
    # Convert posted_at to timestamp
    df = df.withColumn("posted_at", col("posted_at").cast("timestamp"))
    df = df.withColumn("frontpage", col("frontpage").cast("integer"))

    # Extract hour from posted_at
    hour_udf = udf(lambda x: x.hour if x else None, IntegerType())
    df = df.withColumn("posted_hour", hour_udf(col("posted_at")))
    df = df.fillna({"title": "", "source_text": "", "posted_at": ""})

    #some preprocessing done when training model
    #applying the pipeline to it
    df_with_preds = pipeline_model.transform(df)
    df_with_preds.select('aid','comments','votes','source_text','title','frontpage','prediction').show()

# %%
ssc = StreamingContext(sc, 10)

# %%
lines = ssc.socketTextStream("seppe.net", 7778)
lines.foreachRDD(process)

# %%
ssc_t = StreamingThread(ssc)
ssc_t.start()
# Out:
# ========= 2024-05-25 17:05:10 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40472361|       0|    1|GitHub - wuyasong...|Show HN: Image To...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:05:20 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40472364|       0|    2|macOS 15 to bring...|Apple plans macOS...|        0|       0.0|
# |40472374|       0|    5|Optimizing your t...|Optimize Your Tal...|        1|       1.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:05:30 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40472400|       5|    7|Bloomberg - Are y...|Elon Musk's Commu...|        1|       1.0|
# |40472409|       0|    1|Race to Alaska\n\...|R2AK – No motor, ...|        0|       0.0|
# |40472427|       0|    1|Simple.css\n\n# S...|          Simple.css|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:05:40 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40472472|       0|    2|Use Markdown in G...|Google Docs Suppo...|        0|       0.0|
# |40472479|       0|    1|GitHub - Olshansk...|Postgres for Ever...|        0|       0.0|
# |40472483|       3|    1|Warlords Battlecr...|Favourite old-sch...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:05:50 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40472500|       0|    1|Like rocks, like ...|Like Rocks, Like ...|        0|       0.0|
# |40472511|       0|    1|Just a moment...\...|Can Generative AI...|        0|       0.0|
# |40472532|       0|    1|Normalized compre...|Normalised Compre...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:06:00 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40472539|       0|    5|signalfd is usele...| Signalfd Is Useless|        1|       1.0|
# |40472546|       0|    4|Don Knuth’s MIP, ...|Don Knuth's MIP, ...|        1|       1.0|
# |40472553|       0|    1|[2201.03545] A Co...|A ConvNet for the...|        0|       0.0|
# |40472559|       0|    6|Abort Bars\n\n< >...|Abort Bars: A Sug...|        1|       1.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:06:10 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40472571|       0|    3|         wsj.com\n\n|Behind the Scenes...|        0|       1.0|
# |40472584|       0|    2|How to build a te...|How to build a te...|        0|       0.0|
# |40472602|       0|    3|Smart email built...|               Tatem|        0|       1.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:06:20 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40472629|       0|    2|Explore\n\n  * Fr...|             Read.cv|        0|       0.0|
# |40472636|       0|    2|Charm\n\nCharm\n\...|               Charm|        0|       0.0|
# |40472640|       0|    1|What is...wok hei...|    What Is Wok Hei?|        0|       0.0|
# |40472642|       0|    1|Kabosu Dead: Belo...|Kabosu Dies: Belo...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:06:30 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40472646|       0|    1|Webix: JavaScript...|               Webix|        0|       0.0|
# |40472654|       0|    1|Community Softwar...|Community Softwar...|        0|       0.0|
# |40472659|       0|    6|HackNote\n\n# A S...|            HackNote|        1|       1.0|
# |40472721|       0|    1|Aceternity UI\n\n...|Aceternity UI: Ma...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:06:40 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40472765|       0|    2|Blocked\n\n# whoa...|Google AI Overvie...|        0|       0.0|
# |40472785|       0|    1|Chris's Wiki :: b...|Go 1.23 and go:li...|        0|       0.0|
# |40472808|       0|    1|PFAS Explained | ...|PFOA, PFOS and Ot...|        0|       0.0|
# |40472822|       3|    2|         wsj.com\n\n|The Shiba Inu Who...|        0|       0.0|
# |40472838|       0|    1|Judge orders Goog...|Judge orders Goog...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:06:50 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40472842|       0|    1|ChatGPT - AI Enco...|Show HN: AI Encou...|        0|       0.0|
# |40472844|       2|    4|Bloomberg - Are y...|CashApp, Chime, S...|        1|       1.0|
# |40472850|       0|    1|What is Mixture-o...|What Is Mixture-o...|        0|       0.0|
# |40472856|       0|    8|The solar industr...|The solar industr...|        1|       1.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:07:00 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40472864|      30|   21|California is gra...|Marijuana surpass...|        1|       1.0|
# |40472889|       0|    2|OSS for Climate E...|The Role of Open ...|        0|       0.0|
# |40472921|       0|    1|Expeditions to AI...|The Future Is Bright|        0|       0.0|
# |40472987|       0|    1|GitHub - touchHLE...|TouchHLE: High-le...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# ========= 2024-05-25 17:07:10 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40472994|       0|    2|GitHub - sinaatal...|RenderCV – A Late...|        0|       0.0|
# |40473000|       0|    1|Hacking Hard-work...|   Hacking Hard-Work|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:07:20 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40473012|       0|    3|MPs urge under-16...|MPs urge under-16...|        0|       1.0|
# |40473014|       0|    2|Angle of repose -...|     Angle of Repose|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:07:30 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40473053|       0|    3|Endless Tools\n\n...|       Endless Tools|        0|       1.0|
# |40473060|       2|    4|America’s premier...|America's premier...|        1|       1.0|
# |40473063|       0|    5|Will Google Have ...|Will Google Have ...|        1|       1.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:07:40 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40473089|       0|    2|'The Miseducation...|Lauryn Hill's 'Mi...|        0|       0.0|
# |40473117|       0|    1|                \n\n|The Cost of a Sub...|        0|       0.0|
# |40473125|       2|    2|GitHub - turbobla...|Where can I find ...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:08:40 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40473128|      24|   25|EU Approves Histo...|  EU Approves AI Act|        1|       1.0|
# |40473130|       0|   10|TechCrunch is par...|Signal's Meredith...|        1|       1.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:08:50 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40473137|       0|    2|Stable Audio - Ge...|        Stable Audio|        0|       0.0|
# |40473161|       0|    1|Consensus in Inte...|Consensus in Inte...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:09:00 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40473166|       0|    4|Compressed-air ve...|Compressed-Air Ve...|        1|       1.0|
# |40473167|       0|    3|Just a moment...\...|           Supertape|        0|       1.0|
# |40473198|       0|    5|GitHub - mistrala...|   Mistral Fine-Tune|        1|       1.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:09:10 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40473206|       2|    2|Google AI Overvie...|Google's A.I. Sea...|        0|       0.0|
# |40473240|       0|    2|This week in KDE:...|This week in KDE:...|        0|       0.0|
# |40473289|       0|    5|Serotonin Affects...|Serotonin Affects...|        1|       1.0|
# |40473340|       2|    1|ICQ\n\n  * Sign I...|ICQ will stop wor...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:09:20 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40473375|       0|    3|Singapore Airline...|Singapore Airline...|        1|       1.0|
# |40473381|       0|    1|Neopythonic: Tail...|Tail Recursion El...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:09:30 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40473382|       0|    2|The 139 Best Book...| Book Covers of 2023|        0|       0.0|
# |40473387|       0|    1|50 Timeless and U...|Timeless and Unfo...|        0|       0.0|
# |40473395|       0|    1|                \n\n|Knot-based Key Ex...|        0|       0.0|
# |40473417|       0|    1|012 - choosing te...|Choosing Technolo...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:09:40 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40473421|       0|    1|C4AI Aya 23 - a H...|C4AI releases two...|        0|       0.0|
# |40473439|       0|    2|Status Monkey - V...|   SVG Status Monkey|        0|       0.0|
# |40473443|       0|    1|Just a moment...\...|Tech Analysis – L...|        0|       0.0|
# |40473446|       0|    2|From Pollution to...|From Pollution to...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:09:50 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40473454|      10|   34|Male birth contro...|Male birth contro...|        1|       1.0|
# |40473464|       0|    3|Don't Panic\n\nDO...|         Don't Panic|        1|       1.0|
# |40473467|       0|    1|‘A tragedy is not...|Post Office lobbi...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:10:00 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40473468|       0|    1|GitHub - kyleneid...|BackgroundMusic: ...|        0|       0.0|
# |40473531|       0|    1|Elon Musk Slams M...|Elon Musk slams M...|        0|       0.0|
# |40473550|       0|    3|Big tech has dist...|Big tech has dist...|        1|       1.0|
# |40473595|       0|    1|Pāṇini: Catching ...|Pāṇini: Catching ...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# ========= 2024-05-25 17:10:10 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40473618|       0|    2|Your parents are ...|Parents are getti...|        0|       0.0|
# |40473619|       0|    1|BenjiPortheault's...|          Discipline|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:10:20 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40473656|       0|    2|Three New Superco...|Three New Superco...|        0|       0.0|
# |40473685|       0|    1|Amelia Wattenberg...|What makes a coun...|        0|       0.0|
# |40473704|       0|    2|World singles map...|       Singles Atlas|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
#
# ========= 2024-05-25 17:10:30 =========
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |     aid|comments|votes|         source_text|               title|frontpage|prediction|
# +--------+--------+-----+--------------------+--------------------+---------+----------+
# |40473725|       0|    3|What's new on PHP...|What's New on PHP...|        0|       0.0|
# +--------+--------+-----+--------------------+--------------------+---------+----------+

# %%
ssc_t.stop()
# Out:
# ----- Stopping... this may take a few seconds -----
# ========= 2024-05-25 17:03:50 =========
# +--------------------+---------+----------+
# |            features|frontpage|prediction|
# +--------------------+---------+----------+
# |[6.0,4.1520477254...|        1|       1.0|
# |[6.0,0.0,0.971620...|        1|       1.0|
# |(259,[0,2,3,4,5,6...|        0|       0.0|
# |[6.0,0.0,0.097162...|        0|       0.0|
# +--------------------+---------+----------+
#
# ========= 2024-05-25 17:04:00 =========
# +--------------------+---------+----------+
# |            features|frontpage|prediction|
# +--------------------+---------+----------+
# |(259,[0,2,3,4,5,6...|        1|       1.0|
# +--------------------+---------+----------+

# %% [markdown]
# Feature Importance

# %%
import numpy as np
import pandas as pd
from pyspark.ml import PipelineModel

# Load the models
model_GBT_tf_idf = PipelineModel.load(r"C:\Users\Romain\databricks\gbt_model").stages[-1].bestModel
model_GBT_w2v = PipelineModel.load(r"C:\Users\Romain\databricks\gbt_modelw2v").stages[-1].bestModel
model_LR_tf_idf = PipelineModel.load(r"C:\Users\Romain\databricks\logistic_model").stages[-1].bestModel
model_LR_w2v = PipelineModel.load(r"C:\Users\Romain\databricks\logistic_modelw2v").stages[-1].bestModel
model_RF_tf_idf = PipelineModel.load(r"C:\Users\Romain\databricks\rf_model").stages[-1].bestModel
model_RF_w2v = PipelineModel.load(r"C:\Users\Romain\databricks\rf_modelw2v").stages[-1].bestModel

# Get feature importances
feature_importances_GBT_tf_idf = model_GBT_tf_idf.featureImportances
feature_importances_GBT_w2v = model_GBT_w2v.featureImportances
feature_importances_RF_tf_idf = model_RF_tf_idf.featureImportances
feature_importances_RF_w2v = model_RF_w2v.featureImportances
print(np.sum(np.abs(model_GBT_tf_idf.featureImportances)))

# Normalizing the logistic regression coefficients
feature_importances_LR_tf_idf = model_LR_tf_idf.coefficients / np.sum(np.abs(model_LR_tf_idf.coefficients))
feature_importances_LR_w2v = model_LR_w2v.coefficients / np.sum(np.abs(model_LR_w2v.coefficients))

features = ["'poster_hour'", "'comments'", "'votes'"]

# Collect feature importances in a list of dictionaries
feature_importances_data = []

for idx, (importance_GBT_tf_idf, importance_GBT_w2v, 
          importance_LR_tf_idf, importance_LR_w2v, 
          importance_RF_tf_idf, importance_RF_w2v) in enumerate(zip(feature_importances_GBT_tf_idf, feature_importances_GBT_w2v, 
                                                                     feature_importances_LR_tf_idf, feature_importances_LR_w2v, 
                                                                     feature_importances_RF_tf_idf, feature_importances_RF_w2v)):
    if (float(importance_GBT_tf_idf) >= 0.04 or float(importance_GBT_w2v) >= 0.04 or
        float(importance_LR_tf_idf) >= 0.04 or float(importance_LR_w2v) >= 0.04 or
        float(importance_RF_tf_idf) >= 0.04 or float(importance_RF_w2v) >= 0.04):
        
        feature_name = features[idx] if idx < len(features) else f"text-mining:{idx}"
        
        feature_importances_data.append({
            "Feature": feature_name,
            "GBT (TF-IDF)": importance_GBT_tf_idf,
            "GBT (Word2Vec)": importance_GBT_w2v,
            "LR (TF-IDF)": importance_LR_tf_idf,
            "LR (Word2Vec)": importance_LR_w2v,
            "RF (TF-IDF)": importance_RF_tf_idf,
            "RF (Word2Vec)": importance_RF_w2v
        })

# Create a DataFrame from the list of dictionaries
df_feature_importances = pd.DataFrame(feature_importances_data)

# Print the DataFrame
print(df_feature_importances)
# Out:
# 1.0000000000000002
# '\n# Normalizing the logistic regression coefficients\nfeature_importances_LR_tf_idf = model_LR_tf_idf.coefficients / np.sum(np.abs(model_LR_tf_idf.coefficients))\nfeature_importances_LR_w2v = model_LR_w2v.coefficients / np.sum(np.abs(model_LR_w2v.coefficients))\n\nfeatures = ["\'poster_hour\'", "\'comments\'", "\'votes\'"]\n\n# Collect feature importances in a list of dictionaries\nfeature_importances_data = []\n\nfor idx, (importance_GBT_tf_idf, importance_GBT_w2v, \n          importance_LR_tf_idf, importance_LR_w2v, \n          importance_RF_tf_idf, importance_RF_w2v) in enumerate(zip(feature_importances_GBT_tf_idf, feature_importances_GBT_w2v, \n                                                                     feature_importances_LR_tf_idf, feature_importances_LR_w2v, \n                                                                     feature_importances_RF_tf_idf, feature_importances_RF_w2v)):\n    if (float(importance_GBT_tf_idf) >= 0.04 or float(importance_GBT_w2v) >= 0.04 or\n        float(importance_LR_tf_idf) >= 0.04 or float(importance_LR_w2v) >= 0.04 or\n        float(importance_RF_tf_idf) >= 0.04 or float(importance_RF_w2v) >= 0.04):\n        \n        feature_name = features[idx] if idx < len(features) else f"text-mining:{idx}"\n        \n        feature_importances_data.append({\n            "Feature": feature_name,\n            "GBT (TF-IDF)": importance_GBT_tf_idf,\n            "GBT (Word2Vec)": importance_GBT_w2v,\n            "LR (TF-IDF)": importance_LR_tf_idf,\n            "LR (Word2Vec)": importance_LR_w2v,\n            "RF (TF-IDF)": importance_RF_tf_idf,\n            "RF (Word2Vec)": importance_RF_w2v\n        })\n\n# Create a DataFrame from the list of dictionaries\ndf_feature_importances = pd.DataFrame(feature_importances_data)\n\n# Print the DataFrame\nprint(df_feature_importances)'
